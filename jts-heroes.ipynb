# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
count = sum(purchase_data["SN"].value_counts())
count = purchase_data["SN"].value_counts()
#count3 = (purchase_data["SN"].value_counts()).nunique
#count4 = count(purchase_data["SN"].value_counts())
#count = purchase_data["SN"].nunique
total_users = pd.DataFrame(count)
#total = sum(count)
#print (count)
#print (sum)

#players = purchase_data["SN"].unique()
#players
#count = (players)
#count = players().value.count

#count_df
total_rows = total_users.count()
print("total players")
print(int(total_rows))
count.describe
# Out:
# total players
# 576
# <bound method NDFrame.describe of Lisosia93        5
# Iral74           4
# Idastidru52      4
# Hada39           3
# Ialallo29        3
#                 ..
# Inasuir29        1
# Chamadarnya73    1
# Firon67          1
# Meosridil82      1
# Saena89          1
# Name: SN, Length: 576, dtype: int64>

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data.head()
#Item_ID_df = purchase_data["Item ID"].value.count()
drop_df = purchase_data.drop_duplicates(subset = ["Item ID"])
drop_df.head()


uitems = len(drop_df.index)
#print(uitems)
#print("this is the number of uitems")
#unique_items = drop_df["Items ID"].count()
#total = unique_items.count()
#print(unique_items)

#uitems_count = (len(unique_items))
#print(uitems_count)
#print("this is unique items count- which is wrong")
#print(Count(Unique_items))

#drop_df.describe() count is correct
#drop_df = drop_df.set_index(["Item ID"])
#              drop_df = drop_df.sort_values(by = ["Item ID"])
#               drop_df


unique_items = drop_df.shape[0]
print(unique_items)

total_rev = purchase_data["Price"].sum()
print (total_rev)

total_purch = purchase_data["Purchase ID"].count()
print (total_purch)

avg  = purchase_data["Price"].mean()
print(avg)
#drop_df = drop_df.sort_values(by = ["Item ID"])
#drop_df.head
purchase_data.head()
# Out:
# 179
# 2379.77
# 780
# 3.050987179487176
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#males = purchd
#males  = (purchase_data["Gender"] == "Male")
#males = len(purchase_data["Gender"] == "Male")
#males = (purchase_data["Gender"] == "Male").sum()
#males = (purchase_data["Gender"]).value_counts().male
#males = (purchase_data.["Gender"]=="Male").counts()

drop_name_df = purchase_data.drop_duplicates(subset = ["SN"])

males = (drop_name_df["Gender"].value_counts().Male)


print (males)

females = (drop_name_df["Gender"].value_counts().Female)

print (females)

others = len(drop_name_df.loc[drop_name_df["Gender"] == "Other / Non-Disclosed",:])


print (others)

test = (drop_name_df["Gender"].value_counts(normalize=True))

test


new = purchase_data.loc[purchase_data["Gender"]=="Male",:].sum()


new

percentmales = (males/(males+females+others))*100
print(percentmales)
print("this is percent males")


percentfemales = (females/(males+females+others))*100
print(percentfemales)
print("this is percent females")

percentothers = (females/(males+females+others))*100
print(percentothers)
print("this is percent others")

total_players = (females+males+others)
print(total_players)
print("this is the number of total players")
# Out:
# 484
# 81
# 11
# 84.02777777777779
# this is percent males
# 14.0625
# this is percent females
# 14.0625
# this is percent others
# 576
# this is the number of total players

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#reset index using gender


#drop_name_df.set_index("Gender")
#drop_name_df

male_df = purchase_data.loc[purchase_data["Gender"] == "Male",:]


malepc = male_df.shape[0]
print(malepc)
print("this is male purchase count")

maleapp = male_df["Price"].mean()
print(maleapp)
print("this is male avg purchase price")

maletpv = male_df["Price"].sum()
print(maletpv)
print("this is male total purchase value")

maleatppp = maletpv/males
print(maleatppp)
print("this is male average total purchase per person")


female_df = purchase_data.loc[purchase_data["Gender"] == "Female",:]


femalepc = female_df.shape[0]
print(femalepc)
print("this is female purchase count")

femaleapp = female_df["Price"].mean()
print(femaleapp)
print("this is female avg purchase price")

femaletpv = female_df["Price"].sum()
print(femaletpv)
print("this is female total purchase value")

femaleatppp = femaletpv/males
print(femaleatppp)
print("this is female average total purchase per person")



other_df = purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed",:]


otherpc = other_df.shape[0]
print(otherpc)
print("this is other purchase count")

otherapp = other_df["Price"].mean()
print(otherapp)
print("this is other avg purchase price")

othertpv = other_df["Price"].sum()
print(othertpv)
print("this is other total purchase value")

otheratppp = othertpv/others
print(otheratppp)
print("this is other average total purchase per person")

purchase_data.head()
# Out:
# 652
# this is male purchase count
# 3.0178527607361953
# this is male avg purchase price
# 1967.64
# this is male total purchase value
# 4.065371900826446
# this is male average total purchase per person
# 113
# this is female purchase count
# 3.203008849557519
# this is female avg purchase price
# 361.94
# this is female total purchase value
# 0.747809917355372
# this is female average total purchase per person
# 15
# this is other purchase count
# 3.3460000000000005
# this is other avg purchase price
# 50.19
# this is other total purchase value
# 4.5627272727272725
# this is other average total purchase per person
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# use drop_name_df

#create bins

bins_names = ["<10","10-14", "15-19", "20-24", "25-29", "30-34", "35-39","40+"]

bins = [0,9.9,14,19,24,29,34,39,122]

drop_name_df['Agegroups'] = pd.cut(drop_name_df['Age'],bins, labels = bins_names, include_lowest = True)

drop_name_df.head(30)


#count9 = purchase_data[purchase_data["Agegroups"] == "<10"].count()

count9 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "<10",:])
print (count9)
print ("this is the count for <10")
count9perc = (count9/total_players)*100
print (count9perc)
print ("this is the percent count for <10")


count9 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "<10",:])
print (count9)
print ("this is the count for count9")
count9perc = (count9/total_players)*100
print (count9perc)
print ("this is the percent count for count9")

count14 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "10-14",:])
print (count14)
print ("this is the count for count14")
count14perc = (count14/total_players)*100
print (count14perc)
print ("this is the percent count for count14")

count19 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "15-19",:])
print (count19)
print ("this is the count for count19")
count19perc = (count19/total_players)*100
print (count19perc)
print ("this is the percent count for count19")

count24 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "20-24",:])
print (count24)
print ("this is the count for count24")
count24perc = (count24/total_players)*100
print (count24perc)
print ("this is the percent count for count24")

count29 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "25-29",:])
print (count29)
print ("this is the count for count29")
count29perc = (count29/total_players)*100
print (count29perc)
print ("this is the percent count for count29")

count34 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "30-34",:])
print (count34)
print ("this is the count for count34")
count34perc = (count34/total_players)*100
print (count34perc)
print ("this is the percent count for count34")

count39 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "35-39",:])
print (count39)
print ("this is the count for count39")
count39perc = (count39/total_players)*100
print (count39perc)
print ("this is the percent count for count39")

count40 = len(drop_name_df.loc[drop_name_df["Agegroups"] == "40+",:])
print (count40)
print ("this is the count for count40")
count40perc = (count40/total_players)*100
print (count40perc)
print ("this is the percent count for count40")
# Out:
# 17
# this is the count for <10
# 2.951388888888889
# this is the percent count for <10
# 17
# this is the count for count9
# 2.951388888888889
# this is the percent count for count9
# 22
# this is the count for count14
# 3.8194444444444446
# this is the percent count for count14
# 107
# this is the count for count19
# 18.57638888888889
# this is the percent count for count19
# 258
# this is the count for count24
# 44.79166666666667
# this is the percent count for count24
# 77
# this is the count for count29
# 13.368055555555555
# this is the percent count for count29
# 52
# this is the count for count34
# 9.027777777777777
# this is the percent count for count34
# 31
# this is the count for count39
# 5.381944444444445
# this is the percent count for count39
# 12
# this is the count for count40
# 2.083333333333333
# this is the percent count for count40
# C:\Users\Buddy\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#
#
# use purchase_data

#create bins

bins_names = ["<10","10-14", "15-19", "20-24", "25-29", "30-34", "35-39","40+"]

bins = [0,9.9,14,19,24,29,34,39,122]

purchase_data['Agegroups'] = pd.cut(purchase_data['Age'],bins, labels = bins_names, include_lowest = True)

purchase_data.head(30)





count9_df = purchase_data.loc[purchase_data["Agegroups"] == "<10",:]

count9pc = count9_df.shape[0]
print(count9pc)
print("this is count9 purchase count")

count9app = count9_df["Price"].mean()
print(count9app)
print("this is count9 avg purchase price")

count9tpv = count9_df["Price"].sum()
print(count9tpv)
print("this is count9 total purchase value")

count9atppp = count9tpv/count9
print(count9atppp)
print("this is count9 average total purchase per person")
# Out:
# 23
# this is count9 purchase count
# 3.353478260869565
# this is count9 avg purchase price
# 77.13
# this is count9 total purchase value
# 4.537058823529412
# this is count9 average total purchase per person

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
ts_df = purchase_data.groupby(['SN'])

purchtotal = ts_df["Price"].sum()

#purchcount = ts_df.sort_values(by=axis-1)
#print(purchtotal)

#print(len(purchtotal))
#print("this is the len of purchcount")

purchcount = ts_df["Purchase ID"].count()
print(purchcount)
print("this is the # of purch count")

#print(ts_df.head(10))
#print(ts_df.describe)


#new_ts_df = pd.DataFrame({"Purchase Count": purchcount,
 #                           "Average Purchase Price": (purchtotal/purchcount)
  #                           "Total Purchase Value":  purchtotal})

new_ts_df = pd.DataFrame({"Purchase Count": purchcount,
                         "Average Purchase Price":(purchtotal/purchcount),
                         "Total Purchase Value":purchtotal})

new_ts_df = new_ts_df.sort_values(by=["Total Purchase Value"],ascending=False)

print(new_ts_df)

purchase_data.head()
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       3
# Yathedeu43       2
# Yoishirrala98    1
# Zhisrisu83       2
# Zontibe81        3
# Name: Purchase ID, Length: 576, dtype: int64
# this is the # of purch count
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10
# ...                     ...                     ...                   ...
# Ililsasya43               1                1.020000                  1.02
# Irilis75                  1                1.020000                  1.02
# Aidai61                   1                1.010000                  1.01
# Chanirra79                1                1.010000                  1.01
# Alo38                     1                1.000000                  1.00
#
# [576 rows x 3 columns]
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Agegroups
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
mpi_groupby = purchase_data.groupby(['Item ID', "Item Name"])

purchtotal = mpi_groupby["Price"].sum()

#print(purchtotal)

itemprice = mpi_groupby["Price"].value()

print(itemprice)
print("this is the itemprice")

purchcount = mpi_groupby["Purchase ID"].count()
print(purchcount)
print("this is the # of purch count")

#print(ts_df.head(10))
#print(ts_df.describe)


mpi_df = pd.DataFrame({"Purchase Count": purchcount,
                         "Item Price": itemprice,
                         "Total Purchase Value":purchtotal})

mpi_df = mpi_df.sort_values(by=["Purchase Count"],ascending=False)

mpi_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e2be8e3c0546> in <module>
#       5 #print(purchtotal)
#       6
# ----> 7 itemprice = mpi_groupby["Price"].value()
#       8
#       9 print(itemprice)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'value'

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
